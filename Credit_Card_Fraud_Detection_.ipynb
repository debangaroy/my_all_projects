# %% [markdown]
# # Credit Card Fraud Detection

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
credit_data=pd.read_csv("/content/creditcard.csv")
credit_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
credit_data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [5 rows x 31 columns]

# %%
credit_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
credit_data["Class"].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
legit=credit_data[credit_data.Class==0]
fraud=credit_data[credit_data.Class==1]

# %%
print(legit.shape)
# Out:
# (284315, 31)

# %%
print(fraud.shape)
# Out:
# (492, 31)

# %%
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
credit_data.groupby("Class").mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
legit_sample=legit.sample(n=492)
legit_sample.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 111773   72363.0  1.435574 -1.217424  0.313066 -1.742343 -0.951298  0.699224
# 228231  145411.0  2.029099  0.250382 -1.711912  1.168012  0.755121 -0.580968
# 91701    63590.0 -3.779876 -1.906684  0.849758  3.788975  2.166087 -1.270688
# 115712   73983.0  1.193978  0.447899  0.571732  2.249148  0.194758  0.526352
# 59782    49000.0 -1.440152  1.585816  0.466443 -0.011823 -0.408018 -0.154515
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 111773 -1.336386  0.143792 -1.964335  ... -0.025419  0.334059 -0.169289
# 228231  0.575195 -0.288910 -0.146568  ...  0.079688  0.480532 -0.066159
# 91701  -0.657516  0.274214 -1.293508  ... -0.205641  0.029546  0.295243
# 115712 -0.182422  0.164208 -0.482108  ... -0.129280 -0.390800  0.005452
# 59782   0.113210  0.846287 -0.268103  ... -0.181375 -0.416273 -0.138321
#
#              V24       V25       V26       V27       V28  Amount  Class
# 111773 -1.110167  0.422724 -0.026388  0.064956  0.009929   43.40      0
# 228231 -0.439781  0.510112 -0.483970 -0.012514 -0.075910    1.00      0
# 91701  -0.024642  0.707250  0.435076  0.125716 -0.279834    0.00      0
# 115712 -0.812570  0.327857 -0.046429  0.018233  0.017225    0.76      0
# 59782  -0.401198  0.221865  0.298028  0.193980  0.086298   38.14      0
#
# [5 rows x 31 columns]

# %%
new_credit_data=pd.concat([legit_sample,fraud],axis=0)
new_credit_data.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 111773   72363.0  1.435574 -1.217424  0.313066 -1.742343 -0.951298  0.699224
# 228231  145411.0  2.029099  0.250382 -1.711912  1.168012  0.755121 -0.580968
# 91701    63590.0 -3.779876 -1.906684  0.849758  3.788975  2.166087 -1.270688
# 115712   73983.0  1.193978  0.447899  0.571732  2.249148  0.194758  0.526352
# 59782    49000.0 -1.440152  1.585816  0.466443 -0.011823 -0.408018 -0.154515
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 111773 -1.336386  0.143792 -1.964335  ... -0.025419  0.334059 -0.169289
# 228231  0.575195 -0.288910 -0.146568  ...  0.079688  0.480532 -0.066159
# 91701  -0.657516  0.274214 -1.293508  ... -0.205641  0.029546  0.295243
# 115712 -0.182422  0.164208 -0.482108  ... -0.129280 -0.390800  0.005452
# 59782   0.113210  0.846287 -0.268103  ... -0.181375 -0.416273 -0.138321
#
#              V24       V25       V26       V27       V28  Amount  Class
# 111773 -1.110167  0.422724 -0.026388  0.064956  0.009929   43.40      0
# 228231 -0.439781  0.510112 -0.483970 -0.012514 -0.075910    1.00      0
# 91701  -0.024642  0.707250  0.435076  0.125716 -0.279834    0.00      0
# 115712 -0.812570  0.327857 -0.046429  0.018233  0.017225    0.76      0
# 59782  -0.401198  0.221865  0.298028  0.193980  0.086298   38.14      0
#
# [5 rows x 31 columns]

# %%
x=new_credit_data.drop(["Class"],axis=1)
y=new_credit_data["Class"]

# %%
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print(X_train.shape,y_train.shape,X_test.shape,y_test.shape)
# Out:
# (787, 30) (787,) (197, 30) (197,)

# %%
model=LogisticRegression(solver='lbfgs',max_iter=1000)
model.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred=model.predict(X_test)

# %%
model_accuracy_score=accuracy_score(y_test,y_pred)

# %%
print(model_accuracy_score)
# Out:
# 0.9238578680203046
